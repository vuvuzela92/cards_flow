# %%
import pandas as pd
from utils_sql import create_connection, get_db_table
from datetime import datetime, timedelta
from utils_gs import safe_open_spreadsheet, send_df_to_google

# %%
# Список для хранения данных по каждому дню
data = []
# Создание подключения к базе данных
connection = create_connection()
# Цикл по количеству дней для расчета
days_count = 52  # Количество дней для расчета
for day in range(days_count):
    date = (datetime.now() - pd.Timedelta(days=day+1)).strftime('%Y-%m-%d')
    print(f"Выполняется запрос за дату: {date}")
    query = f"""
    SELECT * FROM conditions_calculation
    WHERE date = '{date}';
    """
    df_one_day = get_db_table(query, connection)  
    data.append(df_one_day)

connection.close()
# Объединение всех данных в один датафрейм
df = pd.concat(data, ignore_index=True)
# Доступ к Google Sheets
table_name = safe_open_spreadsheet('Условный расчет')
sheet = table_name.worksheet('Справочная информация')
# Преобразование всех столбцов в строковый тип
df = df.astype(str)
# Отправка данных в Google Sheets
send_df_to_google(df, sheet)
# Out:
# Соединение с БД PostgreSQL успешно установлено в 2026-01-21-11:mm
# Выполняется запрос за дату: 2026-01-20
# c:\Users\123\Desktop\cards_flow_git\conditional_calculation\utils_sql.py:64: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_db = pd.read_sql(db_query, connection).fillna(0).infer_objects(copy=False)
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-19
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-18
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-17
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-16
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-15
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-14
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-13
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-12
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-11
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-10
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-09
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-08
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-07
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-06
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-05
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-04
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-03
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-02
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2026-01-01
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-31
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-30
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-29
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-28
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-27
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-26
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-25
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-24
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-23
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-22
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-21
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-20
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-19
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-18
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-17
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-16
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-15
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-14
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-13
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-12
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-11
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-10
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-09
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-08
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-07
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-06
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-05
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-04
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-03
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-02
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-12-01
# Данные из БД загружены в датафрейм
# Выполняется запрос за дату: 2025-11-30
# Данные из БД загружены в датафрейм
# Добавляем только данные
# Дата и время последнего обновления: 2026-01-21 11:46:12
