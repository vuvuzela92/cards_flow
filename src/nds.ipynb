# %%
import sys
# Добавляем путь к вашему файлу utils.py в sys.path
sys.path.append(r'C:\Users\123\Desktop\cards_flow_git')
from my_utils import safe_open_spreadsheet
from my_card_utils import extract_characteristic, prepare_insert_nds_to_unit
import gspread

# %%
# Определяем нужную для извлечения характеристику
characteristic = 'Ставка НДС'
# Извлекаем нужные данные
characteristic_data = extract_characteristic(characteristic)
# Out:
# Получаем данные по ЛК: Даниелян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получаем данные по ЛК: Вектор
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Оганесян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Хачатрян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Старт
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Лопатина
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получаем данные по ЛК: Тоноян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получены данные по 1300 карточкам
# 200
# Получены данные по 1400 карточкам
# 200
# Получаем данные по ЛК: Пилосян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Старт2
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получаем данные по ЛК: Вектор2
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Не найдена характеристика Ставка НДС для nm_id=578783768
# Не найдена характеристика Ставка НДС для nm_id=584611065
# Нет данных по Ставка НДС по 530081807
# Не найдена характеристика Ставка НДС для nm_id=418675057
# Не найдена характеристика Ставка НДС для nm_id=556609586
# Не найдена характеристика Ставка НДС для nm_id=559808972
# Не найдена характеристика Ставка НДС для nm_id=558235099
# Не найдена характеристика Ставка НДС для nm_id=539678511
# Не найдена характеристика Ставка НДС для nm_id=564544381
# Не найдена характеристика Ставка НДС для nm_id=555438982
# Не найдена характеристика Ставка НДС для nm_id=555438980
# Не найдена характеристика Ставка НДС для nm_id=556642245
# Не найдена характеристика Ставка НДС для nm_id=555460684
# Не найдена характеристика Ставка НДС для nm_id=555460683
# Не найдена характеристика Ставка НДС для nm_id=558153398
# Не найдена характеристика Ставка НДС для nm_id=160349238
# Не найдена характеристика Ставка НДС для nm_id=555465026
# Не найдена характеристика Ставка НДС для nm_id=555465025
# Не найдена характеристика Ставка НДС для nm_id=558139329
# Не найдена характеристика Ставка НДС для nm_id=418675785
# Не найдена характеристика Ставка НДС для nm_id=418675161
# Не найдена характеристика Ставка НДС для nm_id=556627323
# Не найдена характеристика Ставка НДС для nm_id=555397021
# Не найдена характеристика Ставка НДС для nm_id=555396593
# Не найдена характеристика Ставка НДС для nm_id=555474044
# Не найдена характеристика Ставка НДС для nm_id=555474045
# Не найдена характеристика Ставка НДС для nm_id=579021794
# Не найдена характеристика Ставка НДС для nm_id=601065276
# Не найдена характеристика Ставка НДС для nm_id=600476934
# Не найдена характеристика Ставка НДС для nm_id=584848231
# Не найдена характеристика Ставка НДС для nm_id=528973639
# Не найдена характеристика Ставка НДС для nm_id=575486692
# Не найдена характеристика Ставка НДС для nm_id=558035269
# Не найдена характеристика Ставка НДС для nm_id=587403087
# Не найдена характеристика Ставка НДС для nm_id=560532130
# Не найдена характеристика Ставка НДС для nm_id=516925884
# Не найдена характеристика Ставка НДС для nm_id=505583565

# %%
characteristic_data
# Out:
# {227463905: 7,
#  155893983: 7,
#  221738965: 7,
#  437953649: 7,
#  583633354: 7,
#  583157401: 7,
#  558258190: 7,
#  558258188: 7,
#  555399564: 7,
#  555399097: 7,
#  495848275: 7,
#  151948248: 7,
#  161209108: 7,
#  467468550: 7,
#  577158156: 7,
#  552323443: 7,
#  151951511: 7,
#  475807989: 7,
#  166878066: 7,
#  475807990: 7,
#  154790374: 7,
#  151948247: 7,
#  198272992: 7,
#  156714038: 7,
#  154790540: 7,
#  588746062: 7,
#  189724920: 5,
#  163432729: 7,
#  153580264: 7,
#  488521520: 7,
#  263428629: 7,
#  160123376: 7,
#  222869973: 7,
#  157372875: 7,
#  159700998: 7,
#  206253885: 7,
#  347661980: 7,
#  151954246: 7,
#  446719984: 7,
#  463494753: 7,
#  444612109: 7,
#  463496595: 7,
#  164096765: 7,
#  220032953: 7,
#  211667471: 7,
#  575418148: 7,
#  365749533: 7,
#  160464592: 7,
#  190744976: 7,
#  160163861: 7,
#  153263860: 7,
#  153264886: 7,
#  153264269: 5,
#  151951814: 7,
#  564546088: 7,
#  451243235: 7,
#  220209030: 7,
#  220209029: 7,
#  225404272: 7,
#  190859882: 5,
#  160308229: 7,
#  242017310: 7,
#  177243019: 5,
#  160298522: 7,
#  203694489: 7,
#  160298519: 7,
#  153089604: 7,
#  578783768: 0,
#  569781776: 7,
#  569781775: 7,
#  569781774: 7,
#  552342943: 7,
#  577156252: 7,
#  172034182: 7,
#  156056295: 7,
#  170731069: 7,
#  160311122: 7,
#  567296779: 7,
#  222396090: 5,
#  220510066: 5,
#  221315369: 5,
#  222388389: 5,
#  221315371: 5,
#  223081193: 5,
#  222396091: 5,
#  220510067: 5,
#  221315370: 5,
#  220510068: 5,
#  234351104: 7,
#  588836710: 7,
#  233158489: 7,
#  233818855: 7,
#  467175081: 7,
#  488490973: 7,
#  488531221: 7,
#  500472436: 7,
#  502504845: 7,
#  500445810: 7,
#  159424117: 7,
#  432457264: 7,
#  424938420: 7,
#  399629384: 7,
#  418285200: 7,
#  399629383: 7,
#  399629382: 7,
#  399629381: 7,
#  399629379: 7,
#  399629380: 7,
#  155882206: 7,
#  165760631: 5,
#  165760485: 5,
#  165760423: 5,
#  153893925: 7,
#  165830143: 7,
#  417425675: 7,
#  473377995: 7,
#  495904083: 7,
#  584611065: 0,
#  456599327: 7,
#  444612108: 7,
#  439691169: 7,
#  580281056: 7,
#  160512810: 7,
#  224938616: 7,
#  249874047: 7,
#  224938615: 7,
#  224938617: 7,
#  418176637: 7,
#  226869729: 7,
#  219015986: 5,
#  338696320: 7,
#  365749529: 7,
#  229004020: 7,
#  565987064: 7,
#  567288209: 7,
#  403403841: 7,
#  403403807: 7,
#  446293356: 7,
#  423590306: 7,
#  404086358: 7,
#  400671071: 7,
#  400671070: 7,
#  400671069: 7,
#  400671067: 7,
#  235763719: 7,
#  235762874: 7,
#  232309155: 7,
#  163427810: 7,
#  235488247: 7,
#  209242884: 7,
#  264730258: 7,
#  233413980: 7,
#  240460956: 7,
#  168167048: 7,
#  467582109: 7,
#  189981083: 7,
#  158424482: 7,
#  222084023: 7,
#  211880882: 7,
#  264041600: 7,
#  263428630: 7,
#  161558132: 7,
#  168166768: 7,
#  256800820: 7,
#  220227484: 7,
#  240504029: 7,
#  180557605: 7,
#  226043199: 7,
#  485418913: 5,
#  542288111: 7,
#  237992142: 7,
#  237992141: 7,
#  564575541: 7,
#  490618032: 7,
#  496435588: 5,
#  190006960: 7,
#  227425226: 7,
#  227425227: 7,
#  227425229: 7,
#  216840612: 7,
#  223111242: 7,
#  217820589: 7,
#  223111244: 7,
#  220477454: 7,
#  216840610: 7,
#  171429665: 7,
#  218693009: 7,
#  223111243: 7,
#  216840611: 7,
#  226471450: 7,
#  226471449: 7,
#  220051053: 7,
#  220051054: 7,
#  399792082: 7,
#  257323009: 7,
#  403345413: 7,
#  245378175: 7,
#  253435553: 7,
#  165875177: 7,
#  157980434: 7,
#  172034180: 7,
#  167824887: 7,
#  241667998: 7,
#  182951293: 7,
#  160325246: 7,
#  451820529: 7,
#  160315059: 7,
#  165971680: 7,
#  372689139: 7,
#  165564960: 7,
#  400671072: 7,
#  165879075: 7,
#  164620808: 7,
#  181081468: 7,
#  165971675: 7,
#  490602801: 7,
#  165313839: 7,
#  403124070: 7,
#  234689079: 7,
#  191031160: 7,
#  445937150: 7,
#  180969596: 7,
#  244449415: 7,
#  451243236: 7,
#  159379273: 7,
#  160872618: 7,
#  181081466: 7,
#  165971674: 7,
#  165159825: 7,
#  156215406: 7,
#  181081462: 7,
#  172064413: 7,
#  176072858: 7,
#  223424183: 7,
#  166273457: 7,
#  185537743: 7,
#  222253331: 7,
#  227385309: 7,
#  165159824: 7,
#  224933558: 7,
#  189763759: 7,
#  224933559: 7,
#  226491965: 7,
#  189992041: 7,
#  156176995: 7,
#  222253332: 7,
#  185537742: 7,
#  181081465: 7,
#  166255118: 7,
#  226491964: 7,
#  226722921: 7,
#  155885912: 7,
#  287231148: 7,
#  211390016: 7,
#  287231149: 7,
#  165159828: 7,
#  224933560: 7,
#  250111569: 7,
#  248266491: 7,
#  248266490: 7,
#  227511989: 7,
#  190636208: 7,
#  248266492: 7,
#  248266494: 7,
#  248266493: 7,
#  249244838: 7,
#  218788970: 7,
#  210557013: 7,
#  218350529: 7,
#  176046290: 7,
#  249110450: 7,
#  249110451: 7,
#  249750984: 7,
#  227511394: 7,
#  163657309: 7,
#  214657817: 7,
#  156389674: 7,
#  226902141: 7,
#  221477009: 7,
#  218467404: 7,
#  218099832: 7,
#  195776185: 7,
#  189974743: 7,
#  156400640: 7,
#  210896586: 7,
#  195776184: 7,
#  163650465: 7,
#  195776183: 7,
#  176072859: 7,
#  221477008: 7,
#  227511393: 7,
#  168158791: 7,
#  155893169: 7,
#  181419877: 7,
#  226902139: 7,
#  181081467: 7,
#  218467405: 7,
#  224400173: 7,
#  224400172: 7,
#  224400171: 7,
#  156382397: 7,
#  156440792: 7,
#  175130918: 7,
#  167996190: 7,
#  160123556: 7,
#  165514577: 7,
#  238825654: 7,
#  176046291: 7,
#  218350528: 7,
#  161377829: 7,
#  166288202: 7,
#  167758195: 7,
#  218049219: 7,
#  195776186: 7,
#  287231150: 7,
#  157383851: 7,
#  156435885: 7,
#  181085116: 7,
#  181536469: 7,
#  181401534: 7,
#  226902138: 7,
#  156425643: 7,
#  181081464: 7,
#  178169082: 7,
#  228497223: 7,
#  210896585: 7,
#  156025979: 7,
#  223079757: 7,
#  163493373: 7,
#  183650289: 7,
#  175130917: 7,
#  163564809: 7,
#  190427538: 7,
#  190427540: 7,
#  190427539: 7,
#  178841968: 7,
#  178841969: 7,
#  248824636: 7,
#  163816641: 7,
#  156408644: 7,
#  155795428: 7,
#  212778045: 7,
#  212778044: 7,
#  212778046: 7,
#  182989147: 7,
#  178638503: 7,
#  228497224: 7,
#  165159816: 7,
#  197508815: 7,
#  163732745: 7,
#  163734835: 7,
#  179198888: 7,
#  179198889: 7,
#  179198887: 7,
#  163732755: 7,
#  156406156: 7,
#  223154843: 7,
#  223154845: 7,
#  223154844: 7,
#  159379380: 7,
#  169904001: 7,
#  197263458: 7,
#  165159830: 7,
#  165159829: 7,
#  165159818: 7,
#  165159821: 7,
#  165159812: 7,
#  165159819: 7,
#  165159813: 7,
#  165159823: 7,
#  165159826: 7,
#  165159822: 7,
#  165159815: 7,
#  167765367: 7,
#  167759488: 7,
#  169903784: 7,
#  264748090: 7,
#  245515045: 7,
#  164278287: 7,
#  164278288: 7,
#  264356620: 7,
#  234957828: 7,
#  180972667: 7,
#  165830377: 7,
#  165791224: 7,
#  165779188: 7,
#  165830293: 7,
#  234586168: 7,
#  234586171: 7,
#  234586170: 7,
#  165308401: 7,
#  167904540: 7,
#  306819699: 7,
#  306852219: 7,
#  169380825: 7,
#  155365385: 7,
#  263811564: 7,
#  250510352: 7,
#  224984546: 7,
#  153374636: 7,
#  234586169: 7,
#  190005706: 7,
#  190005705: 7,
#  170411997: 7,
#  170409785: 7,
#  170412003: 7,
#  170409783: 7,
#  170412286: 7,
#  223427407: 7,
#  159090450: 7,
#  223427409: 7,
#  160323943: 7,
#  164764259: 7,
#  159423729: 7,
#  237992094: 7,
#  224984547: 7,
#  165910925: 7,
#  165145225: 7,
#  190589062: 7,
#  164763210: 7,
#  164777942: 7,
#  191883736: 7,
#  168273436: 7,
#  168274812: 7,
#  168281327: 7,
#  168291608: 7,
#  227401062: 7,
#  224744834: 7,
#  224867480: 7,
#  224867479: 7,
#  171282734: 7,
#  194331859: 7,
#  155889448: 7,
#  166721220: 7,
#  166721273: 7,
#  180968903: 7,
#  180968904: 7,
#  176023375: 7,
#  189912802: 7,
#  198244084: 7,
#  161628453: 7,
#  207018104: 7,
#  158385194: 7,
#  154922831: 7,
#  154923275: 7,
#  165538384: 7,
#  174504589: 7,
#  165538385: 7,
#  210685647: 7,
#  165452104: 7,
#  165313076: 7,
#  164463973: 7,
#  164628880: 7,
#  164629278: 7,
#  279957455: 7,
#  159661787: 7,
#  215422161: 7,
#  168512698: 7,
#  156728177: 7,
#  212968274: 7,
#  223389405: 7,
#  215247265: 7,
#  164688117: 7,
#  215247266: 7,
#  160876244: 7,
#  155889412: 7,
#  177618900: 7,
#  177618899: 7,
#  160123463: 7,
#  242590468: 7,
#  157005120: 7,
#  157027213: 7,
#  157006830: 7,
#  171215924: 7,
#  276779614: 7,
#  276779612: 7,
#  276779616: 7,
#  276779613: 7,
#  276779615: 7,
#  159389928: 7,
#  256343971: 7,
#  159328920: 7,
#  166288255: 7,
#  264663947: 7,
#  168089887: 7,
#  153852573: 7,
#  235463565: 7,
#  165420922: 7,
#  166206179: 7,
#  179231042: 7,
#  179231043: 7,
#  179231044: 7,
#  154904599: 7,
#  154899220: 7,
#  235445254: 7,
#  177968225: 7,
#  177968226: 7,
#  177968227: 7,
#  177968228: 7,
#  159751030: 7,
#  159749408: 7,
#  223079758: 7,
#  218788968: 7,
#  168158639: 7,
#  168147844: 7,
#  165562286: 7,
#  167996616: 7,
#  175911219: 7,
#  167996192: 7,
#  190636210: 7,
#  223424182: 7,
#  156164569: 7,
#  181417680: 7,
#  156206896: 7,
#  211390015: 7,
#  226491966: 7,
#  226902140: 7,
#  172064414: 7,
#  172064411: 7,
#  181081463: 7,
#  366716444: 7,
#  175130919: 7,
#  218372140: 7,
#  218372138: 7,
#  241521747: 7,
#  226537144: 7,
#  168510711: 7,
#  218372139: 7,
#  241521746: 7,
#  191531418: 7,
#  191141124: 7,
#  191531419: 7,
#  366716442: 7,
#  366716443: 7,
#  366716447: 7,
#  192010918: 7,
#  191290665: 7,
#  191144576: 7,
#  362339358: 7,
#  362339326: 7,
#  362339323: 7,
#  362339357: 7,
#  191290664: 7,
#  191997815: 7,
#  192010917: 7,
#  210896584: 7,
#  366716446: 7,
#  366716445: 7,
#  210557012: 7,
#  227511988: 7,
#  165971678: 7,
#  165829252: 7,
#  156263192: 7,
#  251324147: 7,
#  190912345: 7,
#  190636207: 7,
#  190636209: 7,
#  165308237: 7,
#  178151746: 7,
#  242217669: 7,
#  160867708: 7,
#  289414175: 7,
#  236326910: 7,
#  272680429: 7,
#  165566175: 7,
#  165551473: 7,
#  365087880: 7,
#  365087879: 7,
#  365087878: 7,
#  236326911: 7,
#  155431429: 7,
#  198369083: 7,
#  179191721: 7,
#  179191720: 7,
#  241667996: 7,
#  176971819: 7,
#  164379400: 7,
#  164379355: 7,
#  248667920: 7,
#  249110452: 7,
#  165447872: 7,
#  175099148: 7,
#  253935777: 7,
#  192147342: 7,
#  192239342: 7,
#  254867134: 7,
#  254867133: 7,
#  176966007: 7,
#  165449306: 7,
#  241667997: 7,
#  180557593: 7,
#  180557592: 7,
#  180557601: 7,
#  180557610: 7,
#  180557608: 7,
#  180557609: 7,
#  180557588: 7,
#  227425228: 7,
#  165830105: 7,
#  164414349: 7,
#  164414347: 7,
#  253440069: 7,
#  164379317: 7,
#  170412285: 7,
#  192421145: 7,
#  163428543: 7,
#  248638796: 7,
#  237992065: 7,
#  180557591: 7,
#  417425677: 7,
#  172935877: 7,
#  362339359: 7,
#  338696322: 7,
#  155432122: 7,
#  155380334: 7,
#  155380264: 7,
#  370456117: 7,
#  172742059: 7,
#  157385867: 7,
#  456522020: 7,
#  161235340: 7,
#  206779039: 7,
#  344070258: 7,
#  439691170: 7,
#  418173160: 7,
#  418170432: 7,
#  451820527: 7,
#  166288041: 7,
#  206779038: 7,
#  254708723: 7,
#  191133484: 7,
#  161520997: 7,
#  410104908: 7,
#  410104904: 7,
#  151943981: 7,
#  238877953: 7,
#  235764776: 7,
#  160298520: 7,
#  189954913: 7,
#  241919003: 7,
#  484073756: 7,
#  458250060: 7,
#  227496920: 7,
#  451243234: 7,
#  155800841: 7,
#  153089602: 7,
#  168158530: 7,
#  504198810: 7,
#  473377994: 7,
#  158443624: 7,
#  223154847: 7,
#  164631628: 7,
#  237992066: 7,
#  490711797: 7,
#  170731003: 7,
#  157380704: 7,
#  174232883: 7,
#  155766968: 7,
#  158904325: 7,
#  238865002: 7,
#  153536056: 7,
#  238877959: 7,
#  238877960: 7,
#  246128835: 7,
#  246128837: 7,
#  261078021: 7,
#  165564877: 7,
#  153089605: 7,
#  214867210: 7,
#  162401783: 7,
#  160042700: 7,
#  156669063: 7,
#  173647843: 7,
#  164094039: 7,
#  162399982: 7,
#  153288253: 7,
#  153288012: 7,
#  227496921: 7,
#  238877954: 7,
#  238877956: 7,
#  238877957: 7,
#  305410813: 7,
#  471341942: 7,
#  474824418: 7,
#  398171210: 7,
#  440635747: 7,
#  495763496: 7,
#  495763497: 7,
#  495763499: 7,
#  495763500: 7,
#  495763501: 7,
#  449156411: 7,
#  439694082: 7,
#  473489725: 7,
#  451243237: 7,
#  153535357: 7,
#  153535198: 7,
#  226858517: 7,
#  226858518: 7,
#  226858519: 7,
#  468722385: 7,
#  498730087: 7,
#  156029434: 7,
#  157377636: 7,
#  158444577: 7,
#  467009045: 7,
#  197737344: 7,
#  164463975: 7,
#  153536055: 7,
#  151944851: 7,
#  229155583: 7,
#  229155582: 7,
#  216742172: 7,
#  229155557: 7,
#  229155558: 7,
#  168103192: 7,
#  197745722: 7,
#  197745721: 7,
#  197745720: 7,
#  197745719: 7,
#  203195613: 7,
#  203195615: 7,
#  203195612: 7,
#  203195614: 7,
#  197737343: 7,
#  197737342: 7,
#  197136304: 7,
#  162399083: 7,
#  229155563: 7,
#  229155566: 7,
#  229155567: 7,
#  229155565: 7,
#  197731430: 7,
#  197143511: 7,
#  197143513: 7,
#  197143512: 7,
#  467438460: 7,
#  229155575: 7,
#  229155572: 7,
#  197107134: 7,
#  197767762: 7,
#  197249391: 7,
#  197107135: 7,
#  233839561: 7,
#  197595177: 7,
#  197772382: 7,
#  197595175: 7,
#  197595178: 7,
#  197243971: 7,
#  197131635: 7,
#  197767240: 7,
#  197131638: 7,
#  197731279: 7,
#  197136306: 7,
#  197136305: 7,
#  203080812: 7,
#  203160544: 7,
#  203160543: 7,
#  203160545: 7,
#  203160546: 7,
#  229155559: 7,
#  229155555: 7,
#  228943343: 7,
#  229155584: 7,
#  197673725: 7,
#  500136442: 7,
#  539908543: 7,
#  539908542: 7,
#  197252210: 7,
#  197100320: 7,
#  197769914: 7,
#  197100319: 7,
#  203224426: 7,
#  203224425: 7,
#  203224424: 7,
#  203224423: 7,
#  156406157: 7,
#  202337151: 7,
#  202337152: 7,
#  202337150: 7,
#  168508988: 7,
#  500136443: 7,
#  203241849: 7,
#  203241852: 7,
#  203241847: 7,
#  203241855: 7,
#  229155595: 7,
#  229155596: 7,
#  229155594: 7,
#  229155597: 7,
#  156030244: 7,
#  198622883: 7,
#  197105669: 7,
#  197105667: 7,
#  197105666: 7,
#  197731711: 7,
#  156694555: 7,
#  188576894: 7,
#  203080810: 7,
#  203080808: 7,
#  203080811: 7,
#  197673722: 7,
#  197737341: 7,
#  197673723: 7,
#  197770685: 7,
#  164379466: 7,
#  530081807: 7,
#  401948737: 7,
#  543584232: 7,
#  153089606: 7,
#  158250249: 7,
#  180557585: 7,
#  237992140: 7,
#  500136440: 7,
#  165308508: 7,
#  165565854: 7,
#  185494625: 7,
#  490602800: 7,
#  500136444: 7,
#  365749531: 7,
#  365749532: 7,
#  488647209: 7,
#  495830184: 7,
#  348186796: 7,
#  153852092: 7,
#  233739523: 7,
#  541143267: 7,
#  495763498: 7,
#  458430679: 7,
#  160165106: 7,
#  357420003: 7,
#  357420002: 7,
#  357420000: 7,
#  357419999: 7,
#  189977310: 7,
#  229155574: 7,
#  155733920: 7,
#  497627823: 7,
#  357419998: 7,
#  361998075: 7,
#  444045208: 7,
#  403124069: 7,
#  176967022: 5,
#  176968579: 5,
#  151971787: 5,
#  154709210: 5,
#  154709209: 5,
#  173879832: 5,
#  151968636: 5,
#  418675057: 0,
#  220453241: 5,
#  218705391: 5,
#  218101790: 5,
#  258078493: 5,
#  258078495: 5,
#  258078494: 5,
#  221476101: 5,
#  223400296: 5,
#  152023953: 5,
#  156983329: 5,
#  180557590: 5,
#  180557602: 5,
#  180557607: 5,
#  180557606: 5,
#  180557603: 5,
#  180557604: 5,
#  180557584: 5,
#  180557589: 5,
#  176967906: 5,
#  180557583: 5,
#  167596216: 5,
#  173647753: 5,
#  160115292: 5,
#  153089601: 5,
#  168558392: 5,
#  153089607: 5,
#  162400598: 5,
#  222380902: 5,
#  222380901: 5,
#  221738962: 5,
#  221738959: 5,
#  246128841: 5,
#  246128838: 5,
#  240169193: 5,
#  180961467: 5,
#  180961466: 5,
#  167822867: 5,
#  167788672: 5,
#  167823886: 5,
#  167823203: 5,
#  167823385: 5,
#  160123731: 5,
#  153265101: 5,
#  222839532: 5,
#  222839533: 5,
#  165972331: 5,
#  179818488: 5,
#  165972328: 5,
#  263713618: 5,
#  263713615: 5,
#  165521240: 5,
#  165509906: 5,
#  176020217: 5,
#  164776010: 5,
#  164776011: 5,
#  176020215: 5,
#  176020216: 5,
#  225506893: 5,
#  156027501: 5,
#  210946498: 5,
#  209731299: 5,
#  209711074: 5,
#  209242885: 5,
#  209217179: 5,
#  210693012: 5,
#  209674493: 5,
#  222880191: 5,
#  214940314: 5,
#  189927919: 5,
#  211880881: 5,
#  220824005: 5,
#  207538552: 5,
#  216521419: 5,
#  163360154: 5,
#  205486258: 5,
#  214053863: 5,
#  163357762: 5,
#  155861319: 5,
#  212801467: 5,
#  190019556: 5,
#  175427781: 5,
#  161357668: 5,
#  222070909: 5,
#  165454394: 5,
#  213610890: 5,
#  156176056: 5,
#  166703603: 5,
#  156223086: 5,
#  189981082: 5,
#  211880884: 5,
#  222070910: 5,
#  222084025: 5,
#  156145391: 5,
#  165972372: 5,
#  225243161: 5,
#  225243158: 5,
#  165972335: 5,
#  160322622: 5,
#  153089608: 5,
#  191930286: 5,
#  223354535: 5,
#  173922023: 5,
#  240082651: 5,
#  216521420: 5,
#  155878347: 5,
#  216521418: 5,
#  155870774: 5,
#  213788023: 5,
#  190020417: 5,
#  189801286: 5,
#  205486260: 5,
#  223125487: 5,
#  211880883: 5,
#  224917083: 5,
#  216521417: 5,
#  213579076: 5,
#  163361532: 5,
#  155859373: 5,
#  216521423: 5,
#  223125488: 5,
#  152023954: 5,
#  175427782: 5,
#  156450503: 5,
#  214156215: 5,
#  224917085: 5,
#  214636667: 5,
#  216521422: 5,
#  214156216: 5,
#  216521421: 5,
#  213090220: 5,
#  175427780: 5,
#  222070908: 5,
#  224917084: 5,
#  207538551: 5,
#  190019555: 5,
#  189981081: 5,
#  220824004: 5,
#  223125486: 5,
#  190028136: 5,
#  168060002: 5,
#  166710118: 5,
#  153395164: 5,
#  168059370: 5,
#  166710202: 5,
#  168252840: 5,
#  166090784: 5,
#  190012558: 5,
#  153395163: 5,
#  166110492: 5,
#  223354536: 5,
#  ...}

# %%
# Превращаем список словарей в один словарь: {nm_id: характеристика}
nds_dict_data = {nm_id: nds for d in characteristic_data for nm_id, nds in d.items()}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Превращаем список словарей в один словарь: {nm_id: характеристика}
# ----> 2 nds_dict_data = {nm_id: nds for d in characteristic_data for nm_id, nds in d}
#
# Cell In[10], line 2, in <dictcomp>(.0)
#       1 # Превращаем список словарей в один словарь: {nm_id: характеристика}
# ----> 2 nds_dict_data = {nm_id: nds for d in characteristic_data for nm_id, nds in d}
#
# TypeError: 'int' object is not iterable

# %%
# Открываем гугл таблицу
table = safe_open_spreadsheet('UNIT 2.0 (tested)')
# Определяем лист для вставки данных
sheet = table.worksheet('MAIN (tested)')
# Out:
# [Попытка 1 октрыть доступ к таблице

# %%
# Строка в которой расположены заголовки
headers_loc = 1
# Получаем название искомой колонки
col_header = 'НДС'
# Получаем название колонки с артикулом
col_art_header = 'Артикул'
# Получаем диапазон для вставки
nds_range = get_nds_target_range(headers_loc, col_header, col_art_header, sheet)

# %%
nds_range
# Out:
# 'CL2:CL5803'

# %%
# Получаем значения НДС для вставки данных
nds_values = prepare_insert_nds_to_unit(headers_loc, col_art_header, nds_dict_data, sheet)
# Записываем список списков в диапазон
sheet.update(nds_range, nds_values)
# Out:
# C:\Users\123\AppData\Local\Temp\ipykernel_32724\1077830056.py:4: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update(nds_range, nds_values)
# {'spreadsheetId': '1bvZLSNb-CdWzuyBScL6C6x2fw--U1F8BD9PY4krElc4',
#  'updatedRange': "'MAIN (tested)'!CL2:CL5803",
#  'updatedRows': 5802,
#  'updatedColumns': 1,
#  'updatedCells': 5802}
