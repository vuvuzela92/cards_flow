# %%
import sys
# Добавляем путь к вашему файлу utils.py в sys.path
sys.path.append(r'C:\Users\123\Desktop\cards_flow_git')
from my_utils import safe_open_spreadsheet
from my_card_utils import extract_characteristic, define_the_range, prepare_insert_nds_to_unit
import gspread

# %%
# Определяем нужную для извлечения характеристику
characteristic = 'Ставка НДС'
# Извлекаем нужные данные
characteristic_data = extract_characteristic(characteristic)
# Превращаем список словарей в один словарь: {nm_id: характеристика}
nds_dict_data = {nm_id: nds for d in characteristic_data for nm_id, nds in d.items()}
# Out:
# Получаем данные по ЛК: Даниелян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получены данные по 1300 карточкам
# 200
# Получаем данные по ЛК: Вектор
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получены данные по 1300 карточкам
# 200
# Получаем данные по ЛК: Оганесян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Хачатрян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Старт
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получаем данные по ЛК: Лопатина
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получены данные по 1300 карточкам
# 200
# Получаем данные по ЛК: Тоноян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получены данные по 1200 карточкам
# 200
# Получены данные по 1300 карточкам
# 200
# Получены данные по 1400 карточкам
# 200
# Получены данные по 1500 карточкам
# 200
# Получаем данные по ЛК: Пилосян
# Получены данные по 0 карточкам
# 200
# Получены данные по 100 карточкам
# 200
# Получены данные по 200 карточкам
# 200
# Получены данные по 300 карточкам
# 200
# Получены данные по 400 карточкам
# 200
# Получены данные по 500 карточкам
# 200
# Получены данные по 600 карточкам
# 200
# Получены данные по 700 карточкам
# 200
# Получены данные по 800 карточкам
# 200
# Получены данные по 900 карточкам
# 200
# Получены данные по 1000 карточкам
# 200
# Получены данные по 1100 карточкам
# 200
# Получаем данные по ЛК: Старт2
# Получены данные по 0 карточкам
# 200
# Не найдена характеристика Ставка НДС для nm_id=498730087
# Не найдена характеристика Ставка НДС для nm_id=488916027
# Не найдена характеристика Ставка НДС для nm_id=485418913
# Не найдена характеристика Ставка НДС для nm_id=468642569
# Не найдена характеристика Ставка НДС для nm_id=471341942
# Не найдена характеристика Ставка НДС для nm_id=439694082
# Не найдена характеристика Ставка НДС для nm_id=473489725
# Не найдена характеристика Ставка НДС для nm_id=467582109
# Не найдена характеристика Ставка НДС для nm_id=497627823
# Не найдена характеристика Ставка НДС для nm_id=468245116
# Не найдена характеристика Ставка НДС для nm_id=495763501
# Не найдена характеристика Ставка НДС для nm_id=495763498
# Не найдена характеристика Ставка НДС для nm_id=495763500
# Не найдена характеристика Ставка НДС для nm_id=495763497
# Не найдена характеристика Ставка НДС для nm_id=495763499
# Не найдена характеристика Ставка НДС для nm_id=495763496
# Не найдена характеристика Ставка НДС для nm_id=474824418
# Не найдена характеристика Ставка НДС для nm_id=482273516
# Не найдена характеристика Ставка НДС для nm_id=456534652
# Не найдена характеристика Ставка НДС для nm_id=420200754
# Не найдена характеристика Ставка НДС для nm_id=468722385
# Не найдена характеристика Ставка НДС для nm_id=437806894
# Не найдена характеристика Ставка НДС для nm_id=449156411
# Не найдена характеристика Ставка НДС для nm_id=440635747
# Не найдена характеристика Ставка НДС для nm_id=418675057
# Не найдена характеристика Ставка НДС для nm_id=158929113
# Не найдена характеристика Ставка НДС для nm_id=505094349
# Не найдена характеристика Ставка НДС для nm_id=418674758
# Не найдена характеристика Ставка НДС для nm_id=418675421
# Не найдена характеристика Ставка НДС для nm_id=418675574
# Не найдена характеристика Ставка НДС для nm_id=418675785
# Не найдена характеристика Ставка НДС для nm_id=498730349
# Не найдена характеристика Ставка НДС для nm_id=488919951
# Не найдена характеристика Ставка НДС для nm_id=485421211
# Не найдена характеристика Ставка НДС для nm_id=468670226
# Не найдена характеристика Ставка НДС для nm_id=471345160
# Не найдена характеристика Ставка НДС для nm_id=439691104
# Не найдена характеристика Ставка НДС для nm_id=473491261
# Не найдена характеристика Ставка НДС для nm_id=467590802
# Не найдена характеристика Ставка НДС для nm_id=497632781
# Не найдена характеристика Ставка НДС для nm_id=473479192
# Не найдена характеристика Ставка НДС для nm_id=495763696
# Не найдена характеристика Ставка НДС для nm_id=495763695
# Не найдена характеристика Ставка НДС для nm_id=495763692
# Не найдена характеристика Ставка НДС для nm_id=495763691
# Не найдена характеристика Ставка НДС для nm_id=495763693
# Не найдена характеристика Ставка НДС для nm_id=495763694
# Не найдена характеристика Ставка НДС для nm_id=440636023
# Не найдена характеристика Ставка НДС для nm_id=474885882
# Не найдена характеристика Ставка НДС для nm_id=474825747
# Не найдена характеристика Ставка НДС для nm_id=456536384
# Не найдена характеристика Ставка НДС для nm_id=420201047
# Не найдена характеристика Ставка НДС для nm_id=468722962
# Не найдена характеристика Ставка НДС для nm_id=437807526
# Не найдена характеристика Ставка НДС для nm_id=449156858
# Не найдена характеристика Ставка НДС для nm_id=418675161
# Не найдена характеристика Ставка НДС для nm_id=418665063
# Не найдена характеристика Ставка НДС для nm_id=498731210
# Не найдена характеристика Ставка НДС для nm_id=505575357
# Не найдена характеристика Ставка НДС для nm_id=505691901
# Не найдена характеристика Ставка НДС для nm_id=488929838
# Не найдена характеристика Ставка НДС для nm_id=485431659
# Не найдена характеристика Ставка НДС для nm_id=468721470
# Не найдена характеристика Ставка НДС для nm_id=471352436
# Не найдена характеристика Ставка НДС для nm_id=439668782
# Не найдена характеристика Ставка НДС для nm_id=482926223
# Не найдена характеристика Ставка НДС для nm_id=467616261
# Не найдена характеристика Ставка НДС для nm_id=497647886
# Не найдена характеристика Ставка НДС для nm_id=495764862
# Не найдена характеристика Ставка НДС для nm_id=495764861
# Не найдена характеристика Ставка НДС для nm_id=495764863
# Не найдена характеристика Ставка НДС для nm_id=495764860
# Не найдена характеристика Ставка НДС для nm_id=495764864
# Не найдена характеристика Ставка НДС для nm_id=495764865
# Не найдена характеристика Ставка НДС для nm_id=468240241
# Не найдена характеристика Ставка НДС для nm_id=474873483
# Не найдена характеристика Ставка НДС для nm_id=474838106
# Не найдена характеристика Ставка НДС для nm_id=420202322
# Не найдена характеристика Ставка НДС для nm_id=456544598
# Не найдена характеристика Ставка НДС для nm_id=468725330
# Не найдена характеристика Ставка НДС для nm_id=449160069
# Не найдена характеристика Ставка НДС для nm_id=440636890
# Не найдена характеристика Ставка НДС для nm_id=437808438
# Не найдена характеристика Ставка НДС для nm_id=418675879

# %%
# Открываем гугл таблицу
table = safe_open_spreadsheet('UNIT 2.0 (tested)')
# Определяем лист для вставки данных
sheet = table.worksheet('MAIN (tested)')
# Out:
# [Попытка 1 октрыть доступ к таблице

# %%
# Строка в которой расположены заголовки
headers_loc = 1
# Получаем название искомой колонки
col_header = 'НДС'
# Получаем название колонки с артикулом
col_art_header = 'Артикул'
# Получаем диапазон для вставки
nds_range = get_nds_target_range(headers_loc, col_header, col_art_header, sheet)

# %%
nds_range
# Out:
# 'CL2:CL5803'

# %%
# Получаем значения НДС для вставки данных
nds_values = prepare_insert_nds_to_unit(headers_loc, col_art_header, nds_dict_data, sheet)
# Записываем список списков в диапазон
sheet.update(nds_range, nds_values)
# Out:
# C:\Users\123\AppData\Local\Temp\ipykernel_32724\1077830056.py:4: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet.update(nds_range, nds_values)
# {'spreadsheetId': '1bvZLSNb-CdWzuyBScL6C6x2fw--U1F8BD9PY4krElc4',
#  'updatedRange': "'MAIN (tested)'!CL2:CL5803",
#  'updatedRows': 5802,
#  'updatedColumns': 1,
#  'updatedCells': 5802}
